# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0

# %%
# !pip install uv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 72.4 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/BartekKruczek/PROASSIST_RAG_QA.git
# Out:
# Cloning into 'PROASSIST_RAG_QA'...
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 122 (delta 54), reused 92 (delta 31), pack-reused 0 (from 0)
# Receiving objects: 100% (122/122), 226.44 KiB | 7.08 MiB/s, done.
# Resolving deltas: 100% (54/54), done.

# %%
# %cd /content/PROASSIST_RAG_QA/
# Out:
# /content/PROASSIST_RAG_QA

# %%
# !bash run.sh
# Out:
# Strumieniowane dane wyjściowe obcięte do 5000 ostatnich wierszy.
# nvidia-cublas-cu12       ------------------------------ 444.22 MiB/566.81 MiB
# nvidia-cudnn-cu12        ------------------------------ 505.06 MiB/674.02 MiB
#    Building llama-cpp-python==0.3.16
# ⠋ Preparing packages... (92/96)
# nvidia-cublas-cu12       ------------------------------ 444.79 MiB/566.81 MiB
# nvidia-cudnn-cu12        ------------------------------ 505.06 MiB/674.02 MiB
#    Building llama-cpp-python==0.3.16
# ⠙ Preparing packages... (92/96)
# nvidia-cublas-cu12       ------------------------------ 444.86 MiB/566.81 MiB
# nvidia-cudnn-cu12        ------------------------------ 505.51 MiB/674.02 MiB
#    Building llama-cpp-python==0.3.16
# ⠙ Preparing packages... (92/96)
# nvidia-cublas-cu12       ------------------------------ 444.86 MiB/566.81 MiB
# nvidia-cudnn-cu12        ------------------------------ 506.00 MiB/674.02 MiB
#    Building llama-cpp-python==0.3.16
# ⠙ Preparing packages... (92/96)
# ...
